# %% [markdown]
# #   [Py4Hw User Guide](../UserGuide.ipynb)> 6.2 Manipulating Schematics
# ###  [Next: 6.3 Interactive Workbench](Workbench.ipynb)

# %% [markdown]
# Schematics should be manipulable, so that we can customize some aspects
