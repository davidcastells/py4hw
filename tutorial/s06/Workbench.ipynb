# %% [markdown]
# #   [Py4Hw User Guide](../UserGuide.ipynb)> 6.3 Interactive Workbench
# ###  [Next: 7. Verilog Synthesis / 7.1 RTL Generation](../s07/RTLGeneration.ipynb)

# %% [markdown]
# The interactive workbench allows to visualize and simulate a circuit
